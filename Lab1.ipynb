# %%
Лабораторна робота №1. Інсталяція та налаштування Python-середовища
1) Першим кроком стало створення власного репозиторію для подальшої роботи.

# %% [markdown]
# ![image.png](attachment:46e2c179-c551-47c6-ace4-fdbc5f464b95.png)

# %%
2) Подальші наші кроки спрямовані на встановлення налаштувань Pycharm.
Обираємо необхідну папку і розширення для створення файлу. Після цих кроків
копіюємо посилання з Гітхабу та вставляємо в PyCharm для підв*язки файлу.
Виконуємо ці дії, оскільки така функція надає можливість працювати в команді за потреби. 
Доповнювати, змінювати код.

# %% [markdown]
# ![image.png](attachment:5e9ae200-1ca4-4f71-9285-bcd6e3d1f352.png)

# %%
3) Наступним кроком створюємо перший файл(test).
Прописуємо стандартну фразу "Hello World" та додаємо
до консолі за домогою функції master-comit

# %%
![image.png](attachment:7f9ca414-abd6-4283-a5fe-38b1b6e7d96f.png)

# %%
4) Після виконаних дій маємо нагоду "запушити" у віддалений репозиторій.
Для цього виконаємо дії зображені на фото

# %% [markdown]
# ![image.png](attachment:c219c6ee-aabe-4910-8261-139a754d7367.png)

# %% [markdown]
# ![image.png](attachment:500b240b-c5ad-422e-93ba-a5be89cc002e.png)

# %%
Спостерігаємо зміни в самій структурі репозиторію
