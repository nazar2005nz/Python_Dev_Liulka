# %%
Лабораторна робота №3. Змінні. Базові операції вводу/виводу

# %%
Мета: освоїти роботу зі змінними та операції вводу і виводу

# %%
Хід роботи

# %%
1)Написати програму, яка обчислює значення функції Гауса:
Нижче приклад коду

# %%
import math


def gaussian_function(x, a=1, b=1, c=0):
    """
    Обчислення значення функції Гауса.

    :param x: значення аргументу (x)
    :param a: коефіцієнт амплітуди (a)
    :param b: коефіцієнт, пов'язаний з шириною функції (b)
    :param c: зміщення центру функції (c)
    :return: значення функції Гауса для заданого x
    """
    return a * math.exp(-b * (x - c) ** 2)


# Введення даних користувачем
try:
    x = float(input("Введіть значення x: "))
    a = float(input("Введіть значення a (за замовчуванням 1): ") or 1)
    b = float(input("Введіть значення b (за замовчуванням 1): ") or 1)
    c = float(input("Введіть значення c (за замовчуванням 0): ") or 0)

    result = gaussian_function(x, a, b, c)
    print(f"Значення функції Гауса для x={x}, a={a}, b={b}, c={c}: {result}")
except ValueError:
    print("Будь ласка, введіть коректні числові значення!")

# %% [markdown]
# Результат роботи коду
# ![image.png](attachment:349bc5ba-a81a-4753-88ef-6be56c73cb9a.png)

# %%
Завдання № 2
Ось невелика розповідь:

Якось Джон (John) мав три яблука, Мері (Mary) мала п’ять яблук, а Адам (Adam) мав шість яблук. Усі вони були дуже щасливі та жили довго. Кінець історії.

Ваше завдання:

створіть змінні: john, mary, і adam;

надайте значення змінним. Значення повинні дорівнювати кількості фруктів, якими володіють Джон, Мері, і Адам відповідно;

зберігши числа в змінних, виведіть змінні в один рядок і розділіть їх комами;

тепер створіть нову змінну з ім’ям totalApple, що дорівнює сумі трьох попередніх змінних;

вивести значення, збережене в totalapples, в консоль;

надрукувати рядок та ціле число разом в одному рядку, наприклад, “Загальна кількість яблук:” та total_apples|.

# %%
# Кількість яблук у кожного
john = 3
mary = 5
adam = 6

# Вивести значення змінних в один рядок, розділяючи комами
print(john, mary, adam, sep=",")

# Обчислити загальну кількість яблук
total_apples = john + mary + adam

# Вивести загальну кількість яблук
print("Загальна кількість яблук:", total_apples)

# %% [markdown]
# Результат роботи коду
# ![image.png](attachment:40530325-f7d5-4b4c-83bd-b8ec030e3643.png)

# %%
Завдання № 3
Милі та кілометри – це одиниці довжини або відстані.

Враховуючи, що 1 миля дорівнює приблизно 1.61 кілометрам, напишіть програму, щоб вона перетворила:

милі у кілометри;

кілометри на милі.

Не змінюйте нічого в існуючому коді. Напишіть свій код у місцях, вказаних ###. Протестуйте вашу програму з даними, які надано у вихідному коді.

Зверніть особливу увагу на те, що відбувається всередині функції print(). Проаналізуйте, як ми надаємо кілька аргументів функції та як ми виводимо очікувані дані.

Зауважте, що деякі аргументи всередині функції print() є рядками (наприклад, "miles is", тоді як деякі інші є змінними (наприклад, miles).

Code
Очикуваний вивод:

7.38 miles is 11.88 kilometers

12.25 kilometers is 7.61 miles

# %%
# Перетворення милі -> кілометри та кілометри -> милі
miles = 7.38
kilometers = 12.25

# Константа для переведення
mile_to_kilometer = 1.61

# Додавання коду для перетворення
### Обчислення миль у кілометри
miles_to_km = miles * mile_to_kilometer

### Обчислення кілометрів у милі
km_to_miles = kilometers / mile_to_kilometer

# Виведення результатів
print(miles, "miles is", round(miles_to_km, 2), "kilometers")
print(kilometers, "kilometers is", round(km_to_miles, 2), "miles")

# %% [markdown]
# Результат роботи коду
# ![image.png](attachment:c1ef9cc4-8b84-4231-96fa-4d0a28784d44.png)

# %%
Завдання № 4
Подивіться код у редакторі: він читає “плаваюче” значення, поміщає його у змінну з ім’ям x, і друкує значення змінної з ім’ям y. Ваше завдання - завершити код, щоб оцінити такий вираз:


Результат має бути присвоєний y.

Code
Тестові данні

Приклад вводу

x = 0

x = 1

x = -1

Приклад виводу

y = -1.0

y = 3.0

y = -9.0

# %%
# Читання значення x
x = float(input("Введіть значення x: "))

# Обчислення виразу
y = 3 * x**2 - 2 * x**2 + 3**x - 1

# Виведення результату
print("y =", y)

# %% [markdown]
# Результат роботи коду
# ![image.png](attachment:48aae3b7-6545-43a0-a37b-30e9d112d29c.png)

# %%
Завдання № 5
Код редактора містить коментарі. Спробуйте покращити його: додайте або видаліть коментарі там, де ви вважаєте це доречним (так, іноді видалення коментаря може зробити код більш читабельним) і змініть імена змінних там, де, на вашу думку, це покращить розуміння коду.

# %%
# Встановлення кількості годин для виведення
time_in_hours = 2  # Кількість годин
print("Hours:", time_in_hours)

# %% [markdown]
# Результат коду
# ![image.png](attachment:b19c687e-4c29-43ec-bdf3-77cffe55ce05.png)

# %%
Завдання № 6
Ваше завдання – завершити код, щоб отримати результати чотирьох основних арифметичних операцій.

Результати мають бути виведені у консолі.

Можливо, ви не зможете захистити код від користувача, який хоче ділити на нуль. Пізніше ми взнаємо, як це зробити.

# %% [markdown]
# Результат коду
# ![image.png](attachment:98eb7a56-2100-4676-9e20-7deac90e4dbe.png)

# %%
Завдання № 7
Ваше завдання – завершити код, щоб оцінити такий вираз:
Результат має бути присвоєний y.

Ви можете використовувати додаткові змінні для зменшення виразу (але це не обов’язково). Ретельно тестуйте свій код.

# %%
# Оцінка виразу
x = float(input("Введіть значення x: "))

# Спростимо вираз для обчислення
part1 = 1 / x
part2 = 1 / (x + 1)
part3 = part2 * (x + 1) / x
part4 = 1 / (x + part1 + part3)

# Результат
y = part4

print("y =", y)

# %% [markdown]
# Результат коду
# ![image.png](attachment:7557a421-461b-40c2-b425-09c894750b0c.png)

# %%
Завдання № 8
Ваше завдання - підготувати простий код, здатний порахувати час закінчення періоду часу, вираженого в кількості хвилин (воно може бути як завгодно великим). Час початку вказується у вигляді пари годин (0..23) та хвилин (0..59). Результат повинен бути надрукований на консолі.

Наприклад, якщо подія починається о 12:17 і триває 59 хвилин, вона закінчується о 13:16.

Не турбуйтеся про будь-які недоліки у вашому коді –- це нормально, якщо він приймає неприпустимий час -– найважливіше, що код видає дійсні результати для правильних вхідних даних.

Ретельно перевірте код. Підказка: використання оператора % може бути ключем до успіху.

# %%
# Введення часу початку і тривалості
start_hour = int(input("Введіть годину початку (0-23): "))
start_minute = int(input("Введіть хвилини початку (0-59): "))
duration = int(input("Введіть тривалість у хвилинах: "))

# Додавання тривалості до початкового часу
total_minutes = start_hour * 60 + start_minute + duration
end_hour = (total_minutes // 60) % 24  # Години (з врахуванням доби)
end_minute = total_minutes % 60  # Хвилини

# Виведення результату
print(f"Час завершення: {end_hour}:{end_minute}")

# %% [markdown]
# Результат роботи коду
# ![image.png](attachment:9b06cdb5-7c31-4976-b00e-dab8759e9312.png)

# %% [markdown]
# ![image.png](attachment:67a06231-4518-430a-8ab3-23decc92e1e1.png)

# %%
1)
